# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('CrimeSolutions.gov_Programs.csv')

# %%
# API URL
https://api.usa.gov/crime/fbi/sapi/api/participation/national?api_key=XIGNWQP8tRTZjh5mUOVFlvCNKuf7B5n5CLQdaPaN
# Out:
#   Cell In[2], line 2
#     https://api.usa.gov/crime/fbi/sapi/api/participation/national?api_key=XIGNWQP8tRTZjh5mUOVFlvCNKuf7B5n5CLQdaPaN
#           ^
# SyntaxError: invalid syntax

# %%
# Calculate summary statistics for 'CrimeSolutions'
CrimeSolutions = data.describe()

# Display the summary statistics
print("Summary Statistics for CrimeSolutions:")
print(data)
# Out:
# Summary Statistics for CrimeSolutions:
#      InterventionPublic_ID  Intervention_ID  \
# 0                     7531               39
# 1                     7558               40
# 2                     6028               41
# 3                     7105               42
# 4                     7110               43
# ..                     ...              ...
# 697                   7798             1799
# 698                   7827              327
# 699                   8206              706
# 700                   9300             1800
# 701                   9303             1803
#
#                                                  Title  \
# 0    Program Profile: San Francisco (Calif.) Behavi...
# 1                        Program Profile: Forever Free
# 2    Program Profile: Strong African American Famil...
# 3    Program Profile: Boston (Massachusetts) Reentr...
# 4    Program Profile: Child and Family Traumatic St...
# ..                                                 ...
# ...

# %% [markdown]
# # Inspect the Data

# %%
# Display the first few rows of the dataset to get an overview
print("First 5 rows of the dataset:")
print(data.head())
# Out:
# First 5 rows of the dataset:
#    InterventionPublic_ID  Intervention_ID  \
# 0                   7531               39
# 1                   7558               40
# 2                   6028               41
# 3                   7105               42
# 4                   7110               43
#
#                                                Title  \
# 0  Program Profile: San Francisco (Calif.) Behavi...
# 1                      Program Profile: Forever Free
# 2  Program Profile: Strong African American Famil...
# 3  Program Profile: Boston (Massachusetts) Reentr...
# 4  Program Profile: Child and Family Traumatic St...
#
#                    Evidence Rating  \
# 0            Promising - One study
# 1            Promising - One study
# 2  Effective - More than one study
# 3            Promising - One study
# 4            Promising - One study
#
#                                               Topics  \
# 0                   Courts, Crime & Crime Prevention
# ...

# %% [raw]
# # Check the shape of the dataset (number of rows and columns)
# print("\nShape of the dataset:")
# print(data.shape)

# %%
# Check for missing values
print("\nMissing values:")
print(data.isnull().sum())
# Out:
# Missing values:
# InterventionPublic_ID            0
# Intervention_ID                  0
# Title                            0
# Evidence Rating                  0
# Topics                           0
# Summary                          0
# Randomized Controlled Trial      0
# Program Description              0
# Program Description HTML         0
# Evaluation Methodology           0
# Evaluation Methodology HTML      0
# Evaluation Outcomes              0
# Evaluation Outcomes HTML         0
# Cost                             1
# Implementation Information     336
# Evidence-Base                    1
# Additional References           83
# Age                            157
# Ages                             4
# Gender                          64
# Ethnicity                      148
# DeliverySetting                  2
# Program Type                     2
# Geography                      104
# Targeted Population            253
# Current Program Status           8
# ...

# %%
# Get data types of columns
print("\nData types of columns:")
print(data.dtypes)
# Out:
# Data types of columns:
# InterventionPublic_ID           int64
# Intervention_ID                 int64
# Title                          object
# Evidence Rating                object
# Topics                         object
# Summary                        object
# Randomized Controlled Trial    object
# Program Description            object
# Program Description HTML       object
# Evaluation Methodology         object
# Evaluation Methodology HTML    object
# Evaluation Outcomes            object
# Evaluation Outcomes HTML       object
# Cost                           object
# Implementation Information     object
# Evidence-Base                  object
# Additional References          object
# Age                            object
# Ages                           object
# Gender                         object
# Ethnicity                      object
# DeliverySetting                object
# Program Type                   object
# Geography                      object
# ...

# %%
# Summary statistics
print("\nSummary statistics:")
print(data.describe())
# Out:
# Summary statistics:
#        InterventionPublic_ID  Intervention_ID
# count             702.000000       702.000000
# mean             7130.169516       452.699430
# std               581.728225       298.067646
# min              4995.000000        39.000000
# 25%              6843.250000       242.500000
# 50%              7270.000000       432.500000
# 75%              7549.500000       614.750000
# max              9303.000000      1803.000000

# %%
# Unique values in categorical columns
print("\nUnique values in 'Geography' column:")
print(data['Geography'].unique())
# Out:
# Unique values in 'Geography' column:
# ['Urban' 'Suburban, Urban' 'Rural' nan 'Rural, Suburban, Urban'
#  'Rural, Suburban' 'Rural, Tribal' 'Rural, Urban' 'Suburban'
#  'Urban, Tribal' 'Rural, Suburban, Urban, Tribal' 'Tribal']

# %%
# Unique values in 'Age' column
print("\nUnique values in 'Age' column:")
print(data['Age'].unique())
# Out:
# Unique values in 'Age' column:
# ['18+' '11 - 13' '18 - 32' '7 - 17' '19+' '26 - 55' '10 - 18' '16+' nan
#  '4 - 9, 23 - 33' '13 - 17' '19 - 75' '14 - 19' '14 - 17' '12 - 14'
#  '5 - 10' '12 - 22' '10 - 14' '12 - 17' '0 - 12' '6 - 12' '20 - 60'
#  '10 - 17' '3 - 6, 18+' '11 - 18' '10 - 12' '0 - 2, 18 - 41' '6 - 13, 18+'
#  '10 - 16' '0 - 18' '0 - 10, 18+' '7 - 16' '5 - 15' '11 - 17' '16 - 25'
#  '15 - 18' '0 - 19' '18 - 24' '6 - 10' '3 - 4' '14+' '13 - 45' '12 - 16'
#  '11 - 14' '15 - 70' '35 - 50' '13 - 16' '14 - 18' '18 - 36' '17 - 21'
#  '3 - 12, 23 - 44' '17 - 61' '10 - 17, 18+' '12 - 20' '10 - 15' '4 - 9'
#  '0 - 4, 14 - 24' '10 - 14, 25 - 62' '6 - 11' '3 - 12' '4 - 8, 26 - 42'
#  '3 - 14' '3 - 16' '0 - 7, 16 - 28' '12 - 19' '0 - 24' '1 - 17, 24 - 40'
#  '21+' '2 - 14' '8 - 12, 29 - 41' '0 - 3' '7 - 11' '24 - 45' '13 - 18'
#  '0 - 5' '2 - 5, 21 - 40' '18 - 50' '7 - 9' '11 - 12' '0+'
#  '8 - 9, 14 - 18' '8 - 13' '12 - 18' '9 - 17' '7 - 13' '9 - 11' '16 - 22'
# ...

# %%
# Unique values in 'Ages' column
print("\nUnique values in 'Ages' column:")
print(data['Ages'].unique())
# Out:
# Unique values in 'Ages' column:
# ['[{}]' '[{"min":"18","max":"100"},{}]' '[{"min":"11","max":"13"},{}]'
#  '[{"min":"18","max":"32"},{}]' '[{"min":"7","max":"17"},{}]'
#  '[{"min":"26","max":"55"},{}]' '[{"min":"10","max":"18"},{}]'
#  '[{"min":"16","max":"100"},{}]'
#  '[{"min":"4","max":"9"},{"min":"23","max":"33"},{}]'
#  '[{"min":"13","max":"17"},{}]' '[{"min":"19","max":"75"},{}]'
#  '[{"min":"19","max":"100"},{}]' '[{"min":"14","max":"19"},{}]'
#  '[{"min":"14","max":"17"},{}]' '[{"min":"12","max":"14"},{}]'
#  '[{"min":"5","max":"10"},{}]' '[{"min":"12","max":"22"},{}]'
#  '[{"min":"10","max":"14"},{}]' '[{"min":"12","max":"17"},{}]'
#  '[{"min":"0","max":"12"},{}]' '[{"min":"6","max":"12"},{}]'
#  '[{"min":"20","max":"60"},{}]' nan '[{"min":"10","max":"17"},{}]'
#  '[{"min":"3","max":"6"},{}]' '[{"min":"11","max":"18"},{}]'
#  '[{"min":"10","max":"12"},{}]'
#  '[{"min":"0","max":"2"},{"min":"18","max":"41"},{}]'
#  '[{"min":"6","max":"13"},{"min":"18","max":"100"},{}]'
# ...

# %%
print(data.columns)
# Out:
# Index(['InterventionPublic_ID', 'Intervention_ID', 'Title', 'Evidence Rating',
#        'Topics', 'Summary', 'Randomized Controlled Trial',
#        'Program Description', 'Program Description HTML',
#        'Evaluation Methodology', 'Evaluation Methodology HTML',
#        'Evaluation Outcomes', 'Evaluation Outcomes HTML', 'Cost',
#        'Implementation Information', 'Evidence-Base', 'Additional References',
#        'Age', 'Ages', 'Gender', 'Ethnicity', 'DeliverySetting', 'Program Type',
#        'Geography', 'Targeted Population', 'Current Program Status',
#        'OtherSite', 'Contacts', 'Related Practices', 'DatePostedPublic',
#        'Other Information', 'Topics MPG', 'Factors', 'Topic IDs', 'Factor IDs',
#        'Multisite', 'Semaphore Terms'],
#       dtype='object')

# %%
# Unique values in 'Program Type' column
print("\nUnique values in 'Program Type' column:")
print(data['Program Type'].unique())
# Out:
# Unique values in 'Program Type' column:
# ['Type B' 'Type A' 'Type C']

# %%
# Unique values in 'Geography' column
print("\nUnique values in 'Geography' column:")
print(data['Geography'].unique())
# Out:
# Unique values in 'Geography' column:
# ['Region Z' 'Region Y' 'Region X']

# %%
# Unique values in 'Cost' column
print("\nUnique values in 'Cost' column:")
print(data['Cost'].unique())
# Out:
# Unique values in 'Cost' column:
# [8645 8113 1563 5076 3858 7775 4755 2281 1755 5850 1000 5909 8725 2557
#  7209 1985 2043 5767 4017 1359 8966 4685 6457 4940 4163 9000 9632 4243
#  5002 7464 6954 3927 1124 7691 1157 5986 1822 4091 2697 3237 5697 5807
#  3863 4211 2293 1180 6034 8818 3950 7346 2621 9801 4822 5178 7174 2297
#  3897 2750 1515 2100 8937 9568 4455 9681 4600 3773 8558 7360 3304 1388
#  7651 2423 5469 4944 5138 5466 8513 9374 2676 9321 8139 9046 5859 3392
#  4419 7755 7643 2106 1105 2416 8223 4015 2543 1509 2815 9453 1873 2703]

# %%
# Unique values in 'Evaluation Outcomes' column
print("\nUnique values in 'Evaluation Outcomes' column:")
print(data['Evaluation Outcomes'].unique())
# Out:
# Unique values in 'Evaluation Outcomes' column:
# ['Negative' 'Neutral' 'Positive']

# %% [markdown]
# # Plot a histogram to visualize the distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numeric columns
numeric_columns = [
  'Cost',
  'Age',
]

# Check for missing values in the selected numeric columns
missing_values = data[numeric_columns].isnull().sum()
if missing_values.sum() > 0:
    print("Warning: Missing values found in the selected numeric columns. Please handle missing values.")
else:
    # No missing values, proceed with the pair plot
    data_cleaned = data[numeric_columns]
    
    # Create the pair plot for numeric columns
    sns.pairplot(data_cleaned, height=2)
    plt.suptitle('Pairwise Relationships for Selected Numerical Columns')
    plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Geography', palette='Set1')
plt.xlabel('Geography')
plt.title('Distribution of Data by Geography')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Age', palette='Set1')
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='Age', kde=True)
plt.xlabel('Age')
plt.title('Distribution of Age')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numeric columns
numeric_columns = ['InterventionPublic_ID', 'Intervention_ID', 'Cost']

# Create a pair plot for numeric columns
sns.pairplot(data[numeric_columns])
plt.suptitle('Pairwise Relationships for Numeric Columns')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data (assuming you've already loaded the dataset)
# Replace 'data' with the variable containing your dataset if it's different
data = pd.read_csv('CrimeSolutions.gov_Programs.csv')

# Calculate the distribution of 'Geography'
geography_distribution = data['Geography'].value_counts()

# Create a pie chart to visualize the distribution
plt.figure(figsize=(10, 6))
plt.pie(geography_distribution, labels=geography_distribution.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightpink', 'lightsalmon', 'lightyellow'])

# Customize the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Crime Solutions by Geography')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data (assuming you've already loaded the dataset)
# Replace 'data' with the variable containing your dataset if it's different
data = pd.read_csv('CrimeSolutions.gov_Programs.csv')

# Create a new DataFrame for the counts of each combination of "Gender" and "Evidence Rating"
gender_evidence_counts = data.groupby(['Gender', 'Evidence Rating']).size().unstack(fill_value=0)

# Create a pie chart for each gender category
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
colors = ['skyblue', 'lightcoral', 'lightgreen']

for i, gender in enumerate(gender_evidence_counts.index):
    ax = axes[i]
    ax.pie(gender_evidence_counts.loc[gender], labels=gender_evidence_counts.columns, colors=colors, autopct='%1.1f%%', startangle=90)
    ax.set_title(f'Distribution for {gender}')
    ax.axis('equal')

plt.suptitle('Distribution of Crime Solutions by Gender and Evidence Rating', fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 16
#      13 colors = ['skyblue', 'lightcoral', 'lightgreen']
#      15 for i, gender in enumerate(gender_evidence_counts.index):
# ---> 16     ax = axes[i]
#      17     ax.pie(gender_evidence_counts.loc[gender], labels=gender_evidence_counts.columns, colors=colors, autopct='%1.1f%%', startangle=90)
#      18     ax.set_title(f'Distribution for {gender}')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your data (assuming you've already loaded the dataset)
# Replace 'data' with the variable containing your dataset if it's different
data = pd.read_csv('CrimeSolutions.gov_Programs.csv')

# Create a new DataFrame for the counts of each combination of "Gender" and "Evidence Rating"
gender_evidence_counts = data.groupby(['Gender', 'Evidence Rating']).size().unstack(fill_value=0)

# Create a pie chart for each gender category
fig, axes = plt.subplots(1, len(gender_evidence_counts), figsize=(12, 6))
colors = ['skyblue', 'lightcoral', 'lightgreen']

for i, gender in enumerate(gender_evidence_counts.index):
    ax = axes[i]
    ax.pie(gender_evidence_counts.loc[gender], labels=gender_evidence_counts.columns, colors=colors, autopct='%1.1f%%', startangle=90)
    ax.set_title(f'Distribution for {gender}')
    ax.axis('equal')

plt.suptitle('Distribution of Crime Solutions by Gender and Evidence Rating', fontsize=14)
plt.show()
